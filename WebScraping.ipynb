# %%
import requests ## Pull requests from web pages

from bs4 import BeautifulSoup as bs ### Scrapping modulue

# %%
### load the webpage content

r = requests.get('https://keithgalli.github.io/web-scraping/example.html')



## Convertting to a beautiful soup object

soup = bs(r.content)

## print out our html format of webpage
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    HTML Example
#   </title>
#  </head>
#  <body>
#   <div align="middle">
#    <h1>
#     HTML Webpage
#    </h1>
#    <p>
#     Link to more interesting example:
#     <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#      keithgalli.github.io/web-scraping/webpage.html
#     </a>
#    </p>
#   </div>
#   <h2>
#    A Header
#   </h2>
#   <p>
#    <i>
#     Some italicized text
#    </i>
#   </p>
#   <h2>
#    Another header
#   </h2>
#   <p id="paragraph-id">
#    <b>
#     Some bold text
#    </b>
#   </p>
#  </body>
# </html>

# %%
## This code tells us to get the html format of the webpage with request.get modulue and beautiful soup is scrapping the data from web pages


print(bs(r.content).prettify())
# Out:
# <html>
#  <head>
#   <title>
#    HTML Example
#   </title>
#  </head>
#  <body>
#   <div align="middle">
#    <h1>
#     HTML Webpage
#    </h1>
#    <p>
#     Link to more interesting example:
#     <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#      keithgalli.github.io/web-scraping/webpage.html
#     </a>
#    </p>
#   </div>
#   <h2>
#    A Header
#   </h2>
#   <p>
#    <i>
#     Some italicized text
#    </i>
#   </p>
#   <h2>
#    Another header
#   </h2>
#   <p id="paragraph-id">
#    <b>
#     Some bold text
#    </b>
#   </p>
#  </body>
# </html>

# %% [markdown]
# ### Scrapping the data from beautiful soup module

# %% [markdown]
# ### Find and Find all

# %%
## Find is method of beautiful soup that only fetches single heading or single html command keywords
first_header = soup.find('h2')

print('Fetching only first header from webpage {}'.format(first_header))

print()

## Find_all is method of beautiful soup that fetches list of the html keywords that given in the argument
headers = soup.find_all('h2')

print('Headers for the webpage {}'.format(headers))
# Out:
# Fetching only first header from webpage <h2>A Header</h2>
#
# Headers for the webpage [<h2>A Header</h2>, <h2>Another header</h2>]

# %%
print(soup.find(['h1','h2']))  ## find method only fetches first instances of html keyword that given in the argument
print()
soup.find(['h2','h1'])
## In this case In webpage h1 is coming first compare to h2 so whatever may different order of arguments but it pulls first html keyword instance
# Out:
# <h1>HTML Webpage</h1>
# <h1>HTML Webpage</h1>

# %%
soup.find_all(['h1','h2']) ## It pulls bothe arguments by find_all method
# Out:
# [<h1>HTML Webpage</h1>, <h2>A Header</h2>, <h2>Another header</h2>]

# %%
## You pass the different argument in the find and find_all methods /
"""
With this help of the argument we can able to fetch the data precisely
"""

paragraph = soup.find_all('p')

print(paragraph,sep="\n",end=' ')  ## In this paragraph we fetch all html keyword that given in argument

## If we want to more specify we use attrs argument

para = soup.find_all('p',attrs={'id':'paragraph-id'})
print()
para
# Out:
# [<p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>, <p><i>Some italicized text</i></p>, <p id="paragraph-id"><b>Some bold text</b></p>]
# [<p id="paragraph-id"><b>Some bold text</b></p>]

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    HTML Example
#   </title>
#  </head>
#  <body>
#   <div align="middle">
#    <h1>
#     HTML Webpage
#    </h1>
#    <p>
#     Link to more interesting example:
#     <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#      keithgalli.github.io/web-scraping/webpage.html
#     </a>
#    </p>
#   </div>
#   <h2>
#    A Header
#   </h2>
#   <p>
#    <i>
#     Some italicized text
#    </i>
#   </p>
#   <h2>
#    Another header
#   </h2>
#   <p id="paragraph-id">
#    <b>
#     Some bold text
#    </b>
#   </p>
#  </body>
# </html>

# %%
soup.find('body').find('div')
# Out:
# <div align="middle">
# <h1>HTML Webpage</h1>
# <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
# </div>

# %%
### we can able to nest find methods to shortern our web page request
body = soup.find('body')

print('This original body statement \n',body)
print()
div = body.find('div')
print('This scrutern from body webpage keyword  \n',div)
print()
header = div.find('h1')

print('This is filtered from div statement \n',header)
# Out:
# This original body statement
#  <body>
# <div align="middle">
# <h1>HTML Webpage</h1>
# <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
# </div>
# <h2>A Header</h2>
# <p><i>Some italicized text</i></p>
# <h2>Another header</h2>
# <p id="paragraph-id"><b>Some bold text</b></p>
# </body>
#
# This scrutern from body webpage keyword
#  <div align="middle">
# <h1>HTML Webpage</h1>
# <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
# </div>
#
# This is filtered from div statement
#  <h1>HTML Webpage</h1>

# %%
## We Can able to find the specific string and string methods from webpage to more significant
import re

string_search = soup.find_all('p',string=re.compile('Some'))

print('String contains specified sub string to fetch from webpage \n',string_search)
print()
headers = soup.find_all('h2',string=re.compile('Header'))
print("Find string  header with captial \n",headers)
print()
header = soup.find_all('h2',string=re.compile('(H|h)eader'))
print('String header with capital and without capital \n',header)
# Out:
# String contains specified sub string to fetch from webpage
#  [<p><i>Some italicized text</i></p>, <p id="paragraph-id"><b>Some bold text</b></p>]
#
# Find string  header with captial
#  [<h2>A Header</h2>]
#
# String header with capital and without capital
#  [<h2>A Header</h2>, <h2>Another header</h2>]

# %% [markdown]
# ### Select method (CSS *selector*)

# %%
print(soup.body.prettify())
# Out:
# <body>
#  <div align="middle">
#   <h1>
#    HTML Webpage
#   </h1>
#   <p>
#    Link to more interesting example:
#    <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#     keithgalli.github.io/web-scraping/webpage.html
#    </a>
#   </p>
#  </div>
#  <h2>
#   A Header
#  </h2>
#  <p>
#   <i>
#    Some italicized text
#   </i>
#  </p>
#  <h2>
#   Another header
#  </h2>
#  <p id="paragraph-id">
#   <b>
#    Some bold text
#   </b>
#  </p>
# </body>

# %%
## Selecting all paragraph tags in our website

context = soup.select('p')

print('selecting all paragraphs with out any css selector filter \n',context)
print()
content = soup.select(' div p')

print('Selecting specfic paragraph which follows after first key words that given \n',content)

print()

paragraph = soup.select('h2~p')
print('Select specifc paragraph which has same level as first key words that given \n',paragraph)

bold = soup.select('p#paragraph-id b')
print('Selecting the bold letter tag to select that we use # --> mark to select specific paragraph which has id that contains bold value \n',bold)
# Out:
# selecting all paragraphs with out any css selector filter
#  [<p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>, <p><i>Some italicized text</i></p>, <p id="paragraph-id"><b>Some bold text</b></p>]
#
# Selecting specfic paragraph which follows after first key words that given
#  [<p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>]
#
# Select specifc paragraph which has same level as first key words that given
#  [<p><i>Some italicized text</i></p>, <p id="paragraph-id"><b>Some bold text</b></p>]
# Selecting the bold letter tag to select that we use # --> mark to select specific paragraph which has id that contains bold value
#  [<b>Some bold text</b>]

# %%
"""
Selecting the tags which has direct descendent which means that paragraph tags comes under Same level of paragraph not sub child paragraph
"""
paragraphs = soup.select('body>p')    # Body is parent class to select the paragraphs which has to direct descendent

print('Selecting the paragraph which has fetched from given parent class \n ',paragraphs)

for paragraph in paragraphs:
  print(paragraph.select('i'))
# Out:
# Selecting the paragraph which has fetched from given parent class
#   [<p><i>Some italicized text</i></p>, <p id="paragraph-id"><b>Some bold text</b></p>]
# [<i>Some italicized text</i>]
# []

# %%
## Grab by element which specific property

soup.select('[align=middle]')
# Out:
# [<div align="middle">
#  <h1>HTML Webpage</h1>
#  <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
#  </div>]

# %% [markdown]
# ## Getting Different properties of HTML

# %%
header = soup.find('h2')
"""
## In this method after finding heading h2 , On that tag we can get input string of that tag
## If the tag contains more than one string we can't able to get into string format
## For example if we find div tag that can't able to take string format because of lot of hidden tags/ sub tags
"""
print('The header tags String Be - ',header.string)
print()

div = soup.find('div')

print(div.prettify())

print('It Returns None becuase of lot of string present in div tag',div.string)
## It returns none becuause lot of sub tags in that div so can't able to string those
print()
print('Instead of string we use get_text method ---> It grinds for more than text')

print(div.get_text())
# Out:
# The header tags String Be -  A Header
#
# <div align="middle">
#  <h1>
#   HTML Webpage
#  </h1>
#  <p>
#   Link to more interesting example:
#   <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#    keithgalli.github.io/web-scraping/webpage.html
#   </a>
#  </p>
# </div>
#
# It Returns None becuase of lot of string present in div tag None
#
# Instead of string we use get_text method ---> It grinds for more than text
#
# HTML Webpage
# Link to more interesting example: keithgalli.github.io/web-scraping/webpage.html

# %%
### Get specific property for the element

link_find = soup.find('a')
link_select = soup.select('a')
link_select[0]['href']
# Out:
# 'https://keithgalli.github.io/web-scraping/webpage.html'

# %%
link_select[0]['href']
# Out:
# 'https://keithgalli.github.io/web-scraping/webpage.html'

# %%
paragraphs = soup.select('p#paragraph-id')
print(paragraphs)
paragraphs[0]['id']  ## Can get specific tag and its methods
# Out:
# [<p id="paragraph-id"><b>Some bold text</b></p>]
# 'paragraph-id'

# %%
## path syntax
print(soup.body)
print()
print(soup.body.div)
print()
print(soup.body.div.h1)
print()
print(soup.body.div.h1.string)
# Out:
# <body>
# <div align="middle">
# <h1>HTML Webpage</h1>
# <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
# </div>
# <h2>A Header</h2>
# <p><i>Some italicized text</i></p>
# <h2>Another header</h2>
# <p id="paragraph-id"><b>Some bold text</b></p>
# </body>
#
# <div align="middle">
# <h1>HTML Webpage</h1>
# <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
# </div>
#
# <h1>HTML Webpage</h1>
#
# HTML Webpage

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    HTML Example
#   </title>
#  </head>
#  <body>
#   <div align="middle">
#    <h1>
#     HTML Webpage
#    </h1>
#    <p>
#     Link to more interesting example:
#     <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#      keithgalli.github.io/web-scraping/webpage.html
#     </a>
#    </p>
#   </div>
#   <h2>
#    A Header
#   </h2>
#   <p>
#    <i>
#     Some italicized text
#    </i>
#   </p>
#   <h2>
#    Another header
#   </h2>
#   <p id="paragraph-id">
#    <b>
#     Some bold text
#    </b>
#   </p>
#  </body>
# </html>

# %%
## kowing the relationships of webpage tags

"""
1. Parent  If element has under another element it considered as parent element
2. Sibling If two elements maintains same level of instances that two elements called as sibling element
3. Child  If element is sub tag of another element that given element is child to main tag element
"""

soup.body.find('div').find_next_siblings()  ## In the Div and 2 headers h2 and 2 paragraph p has same level as div
# Out:
# [<h2>A Header</h2>,
#  <p><i>Some italicized text</i></p>,
#  <h2>Another header</h2>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]

# %% [markdown]
# ### Exercises
#
# Go to "https://keithgalli.github.io/web-scraping/webpage.html"

# %%
## loading the webpage

### load the webpage content

r1 = requests.get('https://keithgalli.github.io/web-scraping/webpage.html')



## Convertting to a beautiful soup object

webpage = bs(r1.content)

## print out our html format of webpage
print(webpage.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Keith Galli's Page
#   </title>
#   <style>
#    table {
#     border-collapse: collapse;
#   }
#   th {
#     padding:5px;
#   }
#   td {
#     border: 1px solid #ddd;
#     padding: 5px;
#   }
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#   th {
#     padding-top: 12px;
#     padding-bottom: 12px;
#     text-align: left;
#     background-color: #add8e6;
#     color: black;
#   }
#   .block {
#   width: 100px;
#   /*float: left;*/
#     display: inline-block;
#     zoom: 1;
#   }
#   .column {
#   float: left;
#   height: 200px;
#   /*width: 33.33%;*/
#   padding: 5px;
#   }
#
#   .row::after {
#     content: "";
#     clear: both;
#     display: table;
#   }
#   </style>
#  </head>
#  <body>
#   <h1>
#    Welcome to my page!
#   </h1>
#   <img src="./images/selfie1.jpg" width="300px"/>
#   <h2>
#    About me
#   </h2>
#   <p>
# ...

# %% [markdown]
# ### Grab all the social links from mthe webpage
#
# 1. Do it in 3 different ways

# %%
webpage.find_all('ul',attrs={'class':'socials'})
# Out:
# [<ul class="socials">
#  <li class="social instagram"><b>Instagram: </b><a href="https://www.instagram.com/keithgalli/">https://www.instagram.com/keithgalli/</a></li>
#  <li class="social twitter"><b>Twitter: </b><a href="https://twitter.com/keithgalli">https://twitter.com/keithgalli</a></li>
#  <li class="social linkedin"><b>LinkedIn: </b><a href="https://www.linkedin.com/in/keithgalli/">https://www.linkedin.com/in/keithgalli/</a></li>
#  <li class="social tiktok"><b>TikTok: </b><a href="https://www.tiktok.com/@keithgalli">https://www.tiktok.com/@keithgalli</a></li>
#  </ul>]

# %%
# One way
links = webpage.select('ul.socials a')
actual_links = [link['href'] for link in links ]

actual_links
# Out:
# ['https://www.instagram.com/keithgalli/',
#  'https://twitter.com/keithgalli',
#  'https://www.linkedin.com/in/keithgalli/',
#  'https://www.tiktok.com/@keithgalli']

# %%
## Another way

ulist = webpage.find('ul',attrs={'class':'socials'})
links = ulist.find_all('a')
acutual_link = [ link['href'] for link in links]
acutual_link
# Out:
# ['https://www.instagram.com/keithgalli/',
#  'https://twitter.com/keithgalli',
#  'https://www.linkedin.com/in/keithgalli/',
#  'https://www.tiktok.com/@keithgalli']

# %%
## Third way

"""
If Use select method to direct link element tag which is in under socials
"""

links = webpage.select('li.social a') ## In link of social tags we find the a class tag


print(links)

actual_link = [ link['href'] for link in links]
print()
print('Find the all links of social media')
actual_links
# Out:
# [<a href="https://www.instagram.com/keithgalli/">https://www.instagram.com/keithgalli/</a>, <a href="https://twitter.com/keithgalli">https://twitter.com/keithgalli</a>, <a href="https://www.linkedin.com/in/keithgalli/">https://www.linkedin.com/in/keithgalli/</a>, <a href="https://www.tiktok.com/@keithgalli">https://www.tiktok.com/@keithgalli</a>]
#
# Find the all links of social media
# ['https://www.instagram.com/keithgalli/',
#  'https://twitter.com/keithgalli',
#  'https://www.linkedin.com/in/keithgalli/',
#  'https://www.tiktok.com/@keithgalli']

# %%
table = webpage.select('table.hockey-stats')[0]
print(table.prettify())
# Out:
# <table class="hockey-stats">
#  <thead>
#   <tr>
#    <th class="season" data-sort="">
#     S
#    </th>
#    <th class="team" data-sort="team">
#     Team
#    </th>
#    <th class="league" data-sort="league">
#     League
#    </th>
#    <th class="regular gp" data-sort="gp">
#     GP
#    </th>
#    <th class="regular g" data-sort="g">
#     G
#    </th>
#    <th class="regular a" data-sort="a">
#     A
#    </th>
#    <th class="regular tp" data-sort="tp">
#     TP
#    </th>
#    <th class="regular pim" data-sort="pim">
#     PIM
#    </th>
#    <th class="regular pm" data-sort="pm">
#     +/-
#    </th>
#    <th class="separator">
#    </th>
#    <th class="postseason">
#     POST
#    </th>
#    <th class="postseason gp" data-sort="playoffs-gp">
#     GP
#    </th>
#    <th class="postseason g" data-sort="playoffs-g">
#     G
#    </th>
#    <th class="postseason a" data-sort="playoffs-a">
#     A
#    </th>
#    <th class="postseason tp" data-sort="playoffs-tp">
#     TP
# ...

# %%
import pandas as pd

table = webpage.select('table.hockey-stats')[0]  ### It Returns single element of list that's why we call first and only index of that list
"""
## In here converting scaped data into Data frame
1. Firstly Dataframe needs a df columns or
2. In hockey stats sections there is another table withs its compoenets and that components called as its df columns
3. In order to extract, Using find and find_all methods in soup extracting information from the table
4. Now extracting table rows from that table
"""
#print(table.prettify())

## Extracting the table's columns

columns = table.find('thead').find_all('th')

columns_names = [column.get_text() for column in columns]

print('This is table columns for df but there is repeatation on that table deals this issue out later \n',columns_names)

## Extracting the table's rows

rows = table.find('tbody').find_all('tr')

scrape = []
for i in rows:
  tds = i.find_all('td')
  row = [ tr.get_text().strip()  for tr in tds]
  scrape.append(row)
print()
print(scrape[0])
print()
print('The Scrapped Data Frame \n')
df = pd.DataFrame(scrape,columns=columns_names)

df
# Out:
# This is table columns for df but there is repeatation on that table deals this issue out later
#  ['S', 'Team', 'League', 'GP', 'G', 'A', 'TP', 'PIM', '+/-', '\xa0', 'POST', 'GP', 'G', 'A', 'TP', 'PIM', '+/-']
#
# ['2014-15', 'MIT (Mass. Inst. of Tech.)', 'ACHA II', '17', '3', '9', '12', '20', '', '|', '', '', '', '', '', '', '']
#
# The Scrapped Data Frame
#          S                        Team    League  GP  G   A  TP PIM +/-     \
# 0  2014-15  MIT (Mass. Inst. of Tech.)   ACHA II  17  3   9  12  20      |
# 1  2015-16  MIT (Mass. Inst. of Tech.)   ACHA II   9  1   1   2   2      |
# 2  2016-17  MIT (Mass. Inst. of Tech.)   ACHA II  12  5   5  10   8   0  |
# 3  2017-18                Did not play                                   |
# 4  2018-19  MIT (Mass. Inst. of Tech.)  ACHA III   8  5  10  15   8      |
#
#   POST GP G A TP PIM +/-
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Grab the funfacts in the website

# %%
print(webpage.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Keith Galli's Page
#   </title>
#   <style>
#    table {
#     border-collapse: collapse;
#   }
#   th {
#     padding:5px;
#   }
#   td {
#     border: 1px solid #ddd;
#     padding: 5px;
#   }
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#   th {
#     padding-top: 12px;
#     padding-bottom: 12px;
#     text-align: left;
#     background-color: #add8e6;
#     color: black;
#   }
#   .block {
#   width: 100px;
#   /*float: left;*/
#     display: inline-block;
#     zoom: 1;
#   }
#   .column {
#   float: left;
#   height: 200px;
#   /*width: 33.33%;*/
#   padding: 5px;
#   }
#
#   .row::after {
#     content: "";
#     clear: both;
#     display: table;
#   }
#   </style>
#  </head>
#  <body>
#   <h1>
#    Welcome to my page!
#   </h1>
#   <img src="./images/selfie1.jpg" width="300px"/>
#   <h2>
#    About me
#   </h2>
#   <p>
# ...

# %%
facts = webpage.find_all('ul',attrs={'class':'fun-facts'})

# %%
import re
select_fact = webpage.select('ul.fun-facts li')
select_fact[0].get_text()
select_facts = [ i.find(string=re.compile('is')) for i in select_fact]
facts_with_is = [i for i in select_facts if i]
print(facts_with_is[-1])
print('This is difference in the scrape \n',facts_with_is[-1].find_parent().get_text())
 ## In Given table there is italics in the scrape we did'nt able to capture it so using get parent

facts_is = [i.find_parent().get_text() for i in facts_with_is]
facts_is
# Out:
# The band that I've seen the most times live is the
# This is difference in the scrape
#  The band that I've seen the most times live is the Zac Brown Band
# ['Middle name is Ronald',
#  'Dunkin Donuts coffee is better than Starbucks',
#  "A favorite book series of mine is Ender's Game",
#  'Current video game of choice is Rocket League',
#  "The band that I've seen the most times live is the Zac Brown Band"]

# %% [markdown]
# ## Scrapping the images from the webpage

# %%
print(webpage.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Keith Galli's Page
#   </title>
#   <style>
#    table {
#     border-collapse: collapse;
#   }
#   th {
#     padding:5px;
#   }
#   td {
#     border: 1px solid #ddd;
#     padding: 5px;
#   }
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#   th {
#     padding-top: 12px;
#     padding-bottom: 12px;
#     text-align: left;
#     background-color: #add8e6;
#     color: black;
#   }
#   .block {
#   width: 100px;
#   /*float: left;*/
#     display: inline-block;
#     zoom: 1;
#   }
#   .column {
#   float: left;
#   height: 200px;
#   /*width: 33.33%;*/
#   padding: 5px;
#   }
#
#   .row::after {
#     content: "";
#     clear: both;
#     display: table;
#   }
#   </style>
#  </head>
#  <body>
#   <h1>
#    Welcome to my page!
#   </h1>
#   <img src="./images/selfie1.jpg" width="300px"/>
#   <h2>
#    About me
#   </h2>
#   <p>
# ...

# %%
webpage.select('body img')
# Out:
# [<img src="./images/selfie1.jpg" width="300px"/>,
#  <img alt="Lake Como" src="images/italy/lake_como.jpg" style="height:100%"/>,
#  <img alt="Pontevecchio, Florence" src="images/italy/pontevecchio.jpg" style="height:100%"/>,
#  <img alt="Riomaggiore, Cinque de Terre" src="images/italy/riomaggiore.jpg" style="height:100%"/>,
#  <img src="images/flag.png"/>,
#  <img src="images/flag.png"/>,
#  <img src="images/flag.png"/>,
#  <img src="images/flag.png"/>]

# %%
images= webpage.select('div.row div.column img')

image_url = images[0]['src']
image_url
# Out:
# 'images/italy/lake_como.jpg'

# %%
url = 'https://keithgalli.github.io/web-scraping/'

# %%
img_data = requests.get(url+image_url).content

# %%
with open('lake_como.jpg','wb') as handler:
  handler.write(img_data)

# %% [markdown]
# ### Solve the mystery challenge

# %%
files = webpage.select('div.block a')

reletive_files = [file['href'] for file in files]
reletive_files
# Out:
# ['challenge/file_1.html',
#  'challenge/file_2.html',
#  'challenge/file_3.html',
#  'challenge/file_4.html',
#  'challenge/file_5.html',
#  'challenge/file_6.html',
#  'challenge/file_7.html',
#  'challenge/file_8.html',
#  'challenge/file_9.html',
#  'challenge/file_10.html']

# %%
for i in reletive_files:
   full_url =  url+i
   page = requests.get(full_url)
   file = bs(page.content)
   secret_word = file.find('p',attrs={'id':'secret-word'})
   words = secret_word.get_text()
   print(words)
# Out:
# Make
# sure
# to
# smash
# that
# like
# button
# and
# subscribe
# !!!
